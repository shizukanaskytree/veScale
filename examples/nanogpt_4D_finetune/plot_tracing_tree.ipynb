# %%
import re

yellow_color = "\033[93m"
reset_color = "\033[00m"

class CallStack:
    def __init__(self):
        self.stack = []
        self.call_graph = {}
        self.function_locations = {}
        self.root_functions = set()

    def process_log_line(self, line):
        # 提取函数名和路径：行号        
        call_match = re.search(r'call function (\w+) in (.+:\d+)', line)
        if call_match:
            function_name = call_match.group(1)
            location = call_match.group(2)
            self.stack.append(function_name)
            if len(self.stack) > 1:
                caller = self.stack[-2]
                if caller not in self.call_graph:
                    self.call_graph[caller] = []
                if function_name not in self.call_graph[caller]:
                    self.call_graph[caller].append(function_name)
            else:
                self.root_functions.add(function_name)
            self.function_locations[function_name] = location
        elif 'exit function' in line:
            if self.stack:
                self.stack.pop()

    def process_log(self, log_lines):
        for line in log_lines:
            self.process_log_line(line)

    def print_call_tree(self):
        visited = set()

        def print_subtree(function_name, indent="", is_last=True):
            if function_name in visited:
                return
            visited.add(function_name)
            location = self.function_locations.get(function_name, "")
            connector = "└── " if is_last else "├── "
            # print(f"{indent}{connector}{yellow_color}{function_name}{reset_color}, {location}")
            print(f"{indent}{connector}{function_name}, {location}")
            indent += "    " if is_last else "│   "
            if function_name in self.call_graph:
                child_functions = self.call_graph[function_name]
                for i, callee in enumerate(child_functions):
                    is_last_callee = (i == len(child_functions) - 1)
                    print_subtree(callee, indent, is_last_callee)

        root_functions = list(self.root_functions)
        for i, root_function in enumerate(root_functions):
            is_last_root = (i == len(root_functions) - 1)
            print_subtree(root_function, is_last=is_last_root)

# 读取日志文件并处理
with open('./logs/logs-finetune_4D-host_7c6a3d21f7e2-pid_52125-py/tracing-finetune_4D-20240821_144339.log', 'r') as log_file:
    log_data = log_file.readlines()

# 处理日志并打印调用树
call_stack = CallStack()
call_stack.process_log(log_data)
call_stack.print_call_tree()
# Out:
# ├── get_all_model_patch, /root/vescale_prj/veScale/vescale/model/patch/__init__.py:23
# ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
# │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
# │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
# │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
# │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
# │   ├── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
# │   ├── _init_process_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:364
# │   │   └── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
# │   ├── rng_states, /root/vescale_prj/veScale/vescale/dtensor/random.py:136
# │   ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
# │   ├── get_dim_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:472
# │   ├── get_param_nelements, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:19
# │   │   ├── __torch_dispatch__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:371
# │   │   │   ├── operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:377
# │   │   │   │   ├── _bypass_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:161
# │   │   │   │   │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
# │   │   │   │   ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
# │   │   │   │   │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
# │   │   │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
# │   │   │   │   │   └── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
# │   │   │   │   │       ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
# │   │   │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
# │   │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
# │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
# │   └── reset, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:75
# ├── redistribute_local_args, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:156
# ├── get_dim_size, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:495
# ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
# ├── VocabParallelCrossEntropy, /root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py:149
# ├── check_spec_replicate_at_input_dims, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:235
# │   └── is_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:24
# ├── _get_param_groups, /root/vescale_prj/veScale/vescale/optim/base_optimizer.py:103
# ├── _wrap_output_spec_tensor_meta, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:124
# ├── get_num_params, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:189
# ├── dim_map, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:462
# │   ├── ndim, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:486
# ├── init_parameters, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:269
# │   ├── has_all_attributes, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:108
# │   ├── _distribute_parameter, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:215
# │   │   ├── is_deferred, /root/vescale_prj/veScale/vescale/initialize/deferred_init.py:61
# │   │   │   └── is_dmodule, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:68
# │   │   ├── distribute_tensor, /root/vescale_prj/veScale/vescale/dtensor/api.py:154
# │   │   │   ├── is_rng_supported_mesh, /root/vescale_prj/veScale/vescale/dtensor/random.py:37
# │   │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
# │   │   │   ├── is_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:30
# │   │   │   ├── _scatter_tensor_by_shard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:156
# │   │   │   │   ├── size, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:483
# │   │   │   │   └── _split_tensor, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:69
# │   │   │   ├── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
# │   │   │   ├── _replicate_tensor, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:180
# │   │   │   │   └── mesh_broadcast, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:231
# │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
# │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
# │   │   ├── mesh_scatter, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:44
# ├── _init_weights, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:201
# ├── set_dmodule, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:72
# ├── build_optimizer_group_ranges, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:550
# ├── check_spec_sharding_info_same_at_input_dims, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:243
# │   ├── is_partial, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:39
# ├── build_model_and_main_param_groups, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:601
# ├── RowParallelLinear, /root/vescale_prj/veScale/vescale/model/patch/linear.py:56
# ├── set_patched, /root/vescale_prj/veScale/vescale/model/patch/utils.py:29
# ├── build_model_param_gbuf_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:534
# ├── num_shards, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:454
# ├── map_placements_after_broadcast, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:159
# │   ├── normalize_dim, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:61
# ├── make_new_row_parallel_linear_forward, /root/vescale_prj/veScale/vescale/model/patch/linear.py:32
# ├── __getitem__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:426
# │   ├── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
# │   └── create_child_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:54
# ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
# │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
# │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
# ├── prepare_factory, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:388
# ├── parallelize_module, /root/vescale_prj/veScale/vescale/dmodule/api.py:33
# │   ├── check_and_sanitize_sharding_plan, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:47
# │   ├── initialize_attributes, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:78
# │   ├── initialize_methods, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:435
# │   ├── register_sharding_plan, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:132
# │   │   └── _normalize_one_placements, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:117
# │   ├── from_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:40
# │   ├── is_none, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:54
# ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
# ├── estimate_loss, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:398
# │   └── get_batch, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:252
# ├── build_model_gbuf_range_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:518
# │   └── build_model_gbuf_range, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:454
# │       ├── build_param_sharding_info_for_checkpoint, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:383
# │       ├── build_model_gbuf_param_range_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:399
# │       │   └── normalize, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:37
# │       └── __len__, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:43
# ├── _reshape_prop, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:581
# │   ├── shape, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:442
# │   ├── normalize_sizes, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:192
# │   ├── expand, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:172
# │   │   ├── dim_pad_left, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:157
# │   ├── dim_transpose, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:375
# │   └── normalize_dims, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:65
# ├── _select_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:390
# ├── return_type_tuple_tensors, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:153
# ├── propagate_shape_and_sharding, /root/vescale_prj/veScale/vescale/dtensor/ops/vescale_view_ops.py:49
# │   ├── collect_used_inputs, /root/vescale_prj/veScale/vescale/dtensor/ops/vescale_view_ops.py:72
# │   │   ├── inputs, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:32
# ├── post_patch_submodules, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:378
# ├── generate_redistribute_costs, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:208
# │   └── redistribute_cost, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:404
# │       └── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
# ├── addmm_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:138
# │   ├── _addmm_like_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:87
# │   │   └── output_shape, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:361
# │   ├── gen_einsum_strategies, /root/vescale_prj/veScale/vescale/dtensor/ops/basic_strategy.py:88
# │   │   ├── parse_equation, /root/vescale_prj/veScale/vescale/dtensor/ops/basic_strategy.py:26
# │   │   ├── parse_dims, /root/vescale_prj/veScale/vescale/dtensor/ops/basic_strategy.py:42
# │   │   └── sums, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:501
# ├── layer_norm_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/math_ops.py:373
# │   ├── normalize_to_torch_size, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:79
# │   ├── output_ndim, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:365
# │   └── _replicate_dims_start_at, /root/vescale_prj/veScale/vescale/dtensor/ops/math_ops.py:551
# ├── forward, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:84
# │   ├── _hook, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:96
# │   │   ├── get_sig, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:71
# │   │   └── _convert, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:77
# │   │       └── _convert_by_pi, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:44
# │   │           ├── redistribute, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:505
# │   │           ├── from_local, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:423
# │   ├── redistribute_local_tensor, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:222
# │   │   ├── _decompose_reshard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:50
# │   │   ├── _replicate_then_shard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:34
# │   │   ├── _reshard_to_replicate_with_pad_one_dim, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:90
# │   │   └── _reduce_scatter_to_shard_with_pad, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:194
# │   │       └── mesh_reduce_scatter, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:282
# │   ├── mesh_all_gather, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:309
# ├── from_dim_map, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:510
# ├── init_forward, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:307
# │   ├── get_fwd_plan, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:471
# │   └── get_hook, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:254
# ├── placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:413
# ├── _get, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:413
# ├── gen_fake_kwargs, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:239
# ├── compute_local_shape_and_global_offset, /root/vescale_prj/veScale/vescale/dtensor/_utils.py:51
# │   └── _local_shard_size_on_dim, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:169
# ├── _VocabParallelCrossEntropy, /root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py:43
# ├── _pad_if_needed, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:274
# ├── infer_broadcast_dims_map, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:196
# ├── _make_param_hook, /root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py:190
# ├── prod, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:97
# ├── _rebuild_tensor_from_dtensor_meta, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:29
# ├── linear_pointwise_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/pointwise_ops.py:515
# │   ├── pointwise_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/pointwise_ops.py:411
# │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
# │   └── max_num_shards, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:355
# ├── get_model_param_buffer_dp_views, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:925
# │   └── shard_buffer_among_dp_world, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:920
# ├── is_patched, /root/vescale_prj/veScale/vescale/model/patch/utils.py:25
# ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
# │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
# ├── compute_local_shape, /root/vescale_prj/veScale/vescale/dtensor/_utils.py:24
# ├── new, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:136
# ├── VocabParallelEmbedding, /root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py:38
# ├── main, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:195
# │   ├── init_device_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:594
# │   ├── manual_seed, /root/vescale_prj/veScale/vescale/dtensor/random.py:62
# │   │   ├── init_vescale_rng_tracker, /root/vescale_prj/veScale/vescale/dtensor/random.py:30
# │   │   └── _manual_seed, /root/vescale_prj/veScale/vescale/dtensor/random.py:181
# │   │       └── set_seed, /root/vescale_prj/veScale/vescale/dtensor/random.py:158
# │   └── from_pretrained, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:247
# ├── check_spec_contains_parital, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:221
# ├── patch, /root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py:181
# ├── view_groups, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:267
# │   └── infer_size, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:248
# ├── init_backward, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:350
# │   └── make_backward_hook, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:360
# ├── args_spec, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:98
# ├── configure_optimizers, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:357
# ├── is_tensor_shardable, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:101
# ├── propagate_op_sharding_non_cached, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:165
# │   ├── spec_to_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:170
# │   ├── expand_as_prop, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:693
# │   ├── embedding_rules, /root/vescale_prj/veScale/vescale/dtensor/ops/embedding_ops.py:197
# │   ├── vescale_view_rule_prop, /root/vescale_prj/veScale/vescale/dtensor/ops/vescale_view_ops.py:288
# │   │   └── remove_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/ops/vescale_view_ops.py:231
# │   │       └── replace_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/ops/vescale_view_ops.py:232
# │   ├── transpose_rule, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:45
# │   ├── reshape_prop, /root/vescale_prj/veScale/vescale/dtensor/ops/view_ops.py:679
# │   ├── _prop__scaled_dot_product_flash_attention, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:278
# ├── mm_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:133
# │   ├── _mm_like_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/matrix_ops.py:76
# ├── spec_to_bytes, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:357
# ├── requires_grad_, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:523
# ├── default_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/tensor_ops.py:52
# ├── _propagate_tensor_meta, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:91
# │   ├── gen_fake_args, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:227
# └── _set_bucket, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:379

# %%
import re

class Node:
    def __init__(self, name):
        self.name = name
        self.children = []
        self.visited = False

    def add_child(self, child):
        # 检查是否存在重复子节点
        for existing_child in self.children:
            if existing_child.name == child.name:
                return
        self.children.append(child)

def parse_log_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    root = Node("root")
    stack = [root]

    for line in lines:
        if not line.strip():
            continue

        indent_level = (line.count('-') // 4)

        # 提取函数名和路径：行号
        call_match = re.search(r'call function (\w+) in (.+:\d+)', line)
        # exit_match = re.search(r'exit function (\w+) in (.+:\d+)', line)

        if call_match:
            function_name = call_match.group(1)
            path_line = call_match.group(2)
            line_content = f"{function_name}, {path_line}"
        # elif exit_match:
        #     function_name = exit_match.group(1)
        #     path_line = exit_match.group(2)
        #     line_content = f"exit {function_name} in {path_line}"
        else:
            continue

        node = Node(line_content)

        while len(stack) > indent_level + 1:
            stack.pop()

        # 检查重复调用
        if not any(child.name == node.name for child in stack[-1].children):
            stack[-1].add_child(node)
            stack.append(node)

    return root

def print_tree(node, prefix=""):
    children = node.children
    for index, child in enumerate(children):
        connector = "└── " if index == len(children) - 1 else "├── "
        print(prefix + connector + child.name)
        if child.children:
            extension = "    " if index == len(children) - 1 else "│   "
            print_tree(child, prefix + extension)

# 读取日志文件并生成树结构
file_path = '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/logs-finetune_4D-host_7c6a3d21f7e2-pid_52125-py/tracing-finetune_4D-20240821_144339.log'
# file_path = 'path_to_log_file.log'  # 替换为日志文件的实际路径
root = parse_log_file(file_path)

# 打印树状结构
print_tree(root)
# Out:
# └── main, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:195
#     ├── init_device_mesh, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:48
#     ├── init_device_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:594
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   ├── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   └── _init_process_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:364
#     │       └── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     ├── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     ├── manual_seed, /root/vescale_prj/veScale/vescale/dtensor/random.py:62
#     ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     ├── init_vescale_rng_tracker, /root/vescale_prj/veScale/vescale/dtensor/random.py:30
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/random.py:391
#     │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/random.py:174
#     │       ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/random.py:124
#     │       ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │       └── rng_states, /root/vescale_prj/veScale/vescale/dtensor/random.py:136
#     ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     ├── _manual_seed, /root/vescale_prj/veScale/vescale/dtensor/random.py:181
#     │   ├── set_seed, /root/vescale_prj/veScale/vescale/dtensor/random.py:158
#     │   └── rng_states, /root/vescale_prj/veScale/vescale/dtensor/random.py:136
#     ├── from_pretrained, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:247
#     ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:2
#     ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:157
#     │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:132
#     │   │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:45
#     │   │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:55
#     │   │   └── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:116
#     │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:45
#     │   │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:55
#     │   │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:45
#     │   │   └── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:116
#     │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:55
#     │   │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:45
#     │   │   └── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:116
#     │   ├── __init__, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:116
#     │   ├── _init_weights, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:201
#     │   └── get_num_params, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:189
#     ├── __getitem__, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:399
#     ├── __getitem__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:426
#     │   ├── create_child_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:54
#     │   ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     ├── parallelize_module, /root/vescale_prj/veScale/vescale/dmodule/api.py:33
#     ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     ├── is_dmodule, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:68
#     ├── check_and_sanitize_sharding_plan, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:47
#     ├── initialize_attributes, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:78
#     ├── initialize_methods, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:435
#     ├── register_sharding_plan, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:132
#     │   ├── has_all_attributes, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:108
#     │   ├── ndim, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:486
#     │   ├── _normalize_one_placements, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:117
#     │   │   ├── from_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:40
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── is_none, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:54
#     │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:46
#     │   │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   ├── from_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:40
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── is_none, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:54
#     │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:46
#     │   │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── is_none, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:54
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:46
#     │   │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   ├── is_none, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:54
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:46
#     │   │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   ├── __eq__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:46
#     │   │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:46
#     │   │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │       └── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     ├── init_parameters, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:269
#     │   ├── has_all_attributes, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:108
#     │   ├── _distribute_parameter, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:215
#     │   ├── is_deferred, /root/vescale_prj/veScale/vescale/initialize/deferred_init.py:61
#     │   │   └── is_dmodule, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:68
#     │   ├── distribute_tensor, /root/vescale_prj/veScale/vescale/dtensor/api.py:154
#     │   │   ├── is_rng_supported_mesh, /root/vescale_prj/veScale/vescale/dtensor/random.py:37
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── ndim, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:486
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:30
#     │   │   ├── is_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:24
#     │   │   ├── _scatter_tensor_by_shard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:156
#     │   │   ├── size, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:483
#     │   │   ├── _split_tensor, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:69
#     │   │   ├── mesh_scatter, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:44
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   └── get_dim_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:472
#     │   │   ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   ├── __torch_dispatch__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:371
#     │   │   ├── operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:377
#     │   │   ├── _bypass_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:161
#     │   │   │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:44
#     │   │   ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
#     │   │   │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │   │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── propagate_op_sharding_non_cached, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:165
#     │   │   │   │   ├── spec_to_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:170
#     │   │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   │   ├── default_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/tensor_ops.py:52
#     │   │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │   │   │   ├── _select_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:390
#     │   │   │   │   ├── args_spec, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:98
#     │   │   │   │   ├── return_type_tuple_tensors, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:153
#     │   │   │   │   └── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │       └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:377
#     │   │   ├── _bypass_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:161
#     │   │   │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:44
#     │   │   ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
#     │   │   │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │   │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── requires_grad_, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:523
#     │   ├── _bypass_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:161
#     │   │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:44
#     │   │   ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
#     │   │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   ├── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:44
#     │   │   ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
#     │   │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   ├── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
#     │   │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   ├── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── is_dmodule, /root/vescale_prj/veScale/vescale/dmodule/_dmodule.py:68
#     │   ├── is_rng_supported_mesh, /root/vescale_prj/veScale/vescale/dtensor/random.py:37
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── ndim, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:486
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:30
#     │   │   ├── is_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:24
#     │   │   ├── _scatter_tensor_by_shard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:156
#     │   │   ├── size, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:483
#     │   │   ├── _split_tensor, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:69
#     │   │   ├── mesh_scatter, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:44
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   └── get_dim_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:472
#     │   │   ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── propagate_op_sharding_non_cached, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:165
#     │   │   │   │   ├── spec_to_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:170
#     │   │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   │   ├── default_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/tensor_ops.py:52
#     │   │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │   │   │   ├── _select_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:390
#     │   │   │   │   ├── args_spec, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:98
#     │   │   │   │   ├── return_type_tuple_tensors, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:153
#     │   │   │   │   └── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │       └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   ├── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   ├── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#     │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#     │   │   │       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │   │       └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │   │   ├── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │   │   └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   ├── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │   └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dmodule/placements_interface.py:2
#     │   ├── ndim, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:486
#     │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── ndim, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:486
#     │   │   ├── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   ├── is_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:30
#     │   │   ├── is_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:24
#     │   │   ├── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   ├── _replicate_tensor, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:180
#     │   │   ├── mesh_broadcast, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:231
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#     │   │   │   └── get_dim_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:472
#     │   │   ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │   ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:227
#     │   │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │   │   ├── propagate_op_sharding_non_cached, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:165
#     │   │   │   │   ├── spec_to_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:170
#     │   │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │   │   │   ├── default_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/tensor_ops.py:52
#     │   │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   │   │   │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │   │   │   ├── _select_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:390
#     │   │   │   │   ├── args_spec, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:98
#     │   │   │   │   ├── return_type_tuple_tensors, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:153
#     │   │   │   │   └── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │   │   │       └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
# ...
#             │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#             │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#             │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#             │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#             │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#             │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#             │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#             │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#             │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#             │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#             │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#             ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#             │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#             │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#             │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#             │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:227
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#             │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#             │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#             │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#             │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#             │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#             │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#             │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#             │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#             │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#             │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#             │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#             │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#             ├── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#             │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#             │   │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#             │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#             │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#             │   │   ├── redistribute_local_args, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:156
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#             │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#             │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#             │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#             │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#             │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#             │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#             │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#             │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#             │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#             │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#             │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#             ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#             │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#             │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#             │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#             │   │   ├── redistribute_local_args, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:156
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#             │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#             │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#             │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#             │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#             │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#             │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#             │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#             │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#             │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#             │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#             │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#             ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#             │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#             │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#             │   │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#             │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#             │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#             │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#             │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#             │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#             │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#             │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#             │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#             │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#             │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#             │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#             │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#             │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#             ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#             │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#             │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#             │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#             │   │   ├── redistribute_local_args, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:156
#             │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#             │   │   │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#             │   │   │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#             │   │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#             │   │   │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#             │   │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#             │   │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#             │   │   ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#             │   │   └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#             │   │       ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#             │   │       ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#             │   │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#             │   └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#             │       ├── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#             │       └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#             └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#                 └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:204
#                     ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#                     ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:188
#                     │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:419
#                     │   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#                     │   └── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:385
#                     ├── get_coordinate, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:533
#                     ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#                     │   └── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#                     ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#                     ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#                     ├── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#                     └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#                         ├── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#                         ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#                         └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
