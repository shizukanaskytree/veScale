# %% [markdown]
# ## Complete tree printing

# %%
import re

def parse_log_file(file_path):
    with open(file_path, 'r') as f:
        logs = []
        for line in f:
            # Match for function entry logs with '>' or '-->'
            match_push = re.match(r'^(--+>|\s*>)\s*call function (.+?) in (.+?):(\d+)', line)
            if match_push:
                function_name = match_push.group(2)
                file_path = match_push.group(3)
                line_number = int(match_push.group(4))
                logs.append((function_name, file_path, line_number, "push"))
                continue

            # Match for function exit logs with '<' or '<--'
            match_pop = re.match(r'^(<--+|\s*<)\s*exit function (.+?) in (.+?):(\d+)', line)
            if match_pop:
                function_name = match_pop.group(2)
                file_path = match_pop.group(3)
                line_number = int(match_pop.group(4))
                logs.append((function_name, file_path, line_number, "pop"))
                continue

    return logs

class CallStackNode:
    def __init__(self, function_name, file_path, line_number):
        self.function_name = function_name
        self.file_path = file_path
        self.line_number = line_number
        self.children = []
        self.parent = None

    def add_child(self, child_node):
        child_node.parent = self
        self.children.append(child_node)

    def __repr__(self, level=0, is_last_child=True, parent_last_childs=[]):
        indent = ''
        for parent_last in parent_last_childs:
            indent += '    ' if parent_last else '│   '

        branch = '└── ' if is_last_child else '├── '
        repr_str = f"{indent}{branch}{self.function_name}, {self.file_path}:{self.line_number}\n" # complete
        # repr_str = f"{indent}{branch}{self.function_name}\n" # simple without file path and line number

        for i, child in enumerate(self.children):
            repr_str += child.__repr__(level + 1, i == len(self.children) - 1, parent_last_childs + [is_last_child])
        return repr_str

class CallStackTree:
    def __init__(self):
        self.root = CallStackNode("root", "", 0)
        self.current_node = self.root

    def push(self, function_name, file_path, line_number):
        new_node = CallStackNode(function_name, file_path, line_number)
        self.current_node.add_child(new_node)
        self.current_node = new_node

    def pop(self):
        if self.current_node != self.root:
            self.current_node = self.current_node.parent

    def __repr__(self):
        return self.root.__repr__()

# Parse log file and construct call stack tree
log_file_path = "/root/vescale_prj/veScale/test/parallel/pipeline/instruction/logs-test_schedule-host_f78e8e970a17-pid_199624-py/tracing-test_schedule-20240829_071457.log"
logs = parse_log_file(log_file_path)

call_stack_tree = CallStackTree()

for log in logs:
    function_name, file_path, line_number, operation = log
    if operation == "push":
        call_stack_tree.push(function_name, file_path, line_number)
    elif operation == "pop":
        call_stack_tree.pop()

print(call_stack_tree)
# Out:
# └── root, :0
#     ├── init_device_mesh, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:48
#     │   └── init_device_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:594
#     │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │           ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │           ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │           │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │           ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │           ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │           ├── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │           └── _init_process_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:364
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               └── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     ├── init_ndtimers, /root/vescale_prj/veScale/vescale/ndtimeline/api.py:72
#     │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   ├── get_strategy_size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:261
#     │   │   └── size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:447
#     │   │       └── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_strategy_size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:261
#     │   │   └── size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:447
#     │   │       └── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_strategy_size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:261
#     │   │   └── size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:447
#     │   │       └── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_tensor_parallel_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:315
#     │   │   └── lookup_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:221
#     │   │       └── get_strategy_coordinate, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:188
#     │   │           ├── get_local_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:282
#     │   │           └── get_strategy_coordinate, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:188
#     │   │               └── <listcomp>, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:218
#     │   ├── get_pipeline_parallel_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:290
#     │   │   └── lookup_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:221
#     │   ├── get_data_parallel_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:303
#     │   │   └── lookup_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:221
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/handlers/sock_handler.py:31
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/handlers/handler_base.py:25
#     │   │   └── try_to_connect, /root/vescale_prj/veScale/vescale/ndtimeline/handlers/sock_handler.py:41
#     │   ├── is_internal_vescale, /root/vescale_prj/veScale/vescale/ndtimeline/is_internal.py:22
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:62
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:37
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:2
#     │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:53
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:411
#     │   │       └── init_cuda_dist_associated, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:449
#     │   │           ├── init, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:65
#     │   │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:29
#     │   │           ├── __getitem__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:107
#     │   │           └── init, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:61
#     │   │               ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:77
#     │   │               └── calibrate, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:95
#     │   │                   ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:114
#     │   │                   ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:116
#     │   │                   └── __new__, /root/vescale_prj/veScale/vescale/ndtimeline/logger.py:24
#     │   ├── is_internal_vescale, /root/vescale_prj/veScale/vescale/ndtimeline/is_internal.py:22
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   └── register_timers, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:458
#     │       └── _register_timers, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:475
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │               └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │                   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:164
#     │   └── <listcomp>, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:166
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       └── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     ├── get_global_tensor_parallel_meshes, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:361
#     │   ├── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_tensor_parallel_mesh, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:352
#     │   │   ├── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   │   └── __getitem__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:426
#     │   │       └── create_child_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:54
#     │   │           ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │       ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │       ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │       │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │       ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │       └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     ├── get_linear_pp_module_dep2, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:291
#     │   └── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:86
#     │       ├── get_num_chunks, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:263
#     │       ├── generate_one_forward_mapping, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:160
#     │       │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   ├── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │       │   │   ├── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   │   ├── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   │   ├── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   │   └── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │   │   └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │       └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │   │   └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │       └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │   │   └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │       └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   └── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │       └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │           └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       └── construct_communication_graph, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:110
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           └── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     ├── get_global_tensor_parallel_meshes, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:361
#     ├── <listcomp>, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:635
#     ├── __init__, /root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py:133
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py:46
#     │   │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:603
#     │   │   │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:199
#     │   │   │   └── get_v_schedule, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:455
#     │   │   │       ├── try_v_schedule, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:219
#     │   │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:228
#     │   │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:229
#     │   │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:230
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
# ...
#     │   │       │       │   ├── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:713
#     │   │       │       │   │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   │       │       │   │   ├── get_nccl_p2p_stream, /root/vescale_prj/veScale/vescale/ndtimeline/stream.py:25
#     │   │       │       │   │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │       │   │   └── start_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:510
#     │   │       │       │   │       └── start, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:305
#     │   │       │       │   │           ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │       │   │           ├── getter, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:467
#     │   │       │       │   │           └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │       │   │               └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       │       │   ├── _communicate, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:411
#     │   │       │       │   │   ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   │       │       │   │   ├── _mapping_local_rank_to_target_rank_by_device_mesh, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:96
#     │   │       │       │   │   ├── _mapping_local_rank_to_target_rank_by_device_mesh, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:96
#     │   │       │       │   │   └── _batched_p2p_ops, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:219
#     │   │       │       │   └── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:725
#     │   │       │       │       ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │       │       └── stop_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:527
#     │   │       │       │           └── stop, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:332
#     │   │       │       │               ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │       │               └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │       │                   └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       │       └── cross_mesh_send, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:95
#     │   │       │           ├── get_mapping_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:566
#     │   │       │           │   └── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   │       │           ├── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:713
#     │   │       │           │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   │       │           │   ├── get_nccl_p2p_stream, /root/vescale_prj/veScale/vescale/ndtimeline/stream.py:25
#     │   │       │           │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │           │   └── start_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:510
#     │   │       │           │       └── start, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:305
#     │   │       │           │           ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │           │           ├── getter, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:467
#     │   │       │           │           └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │           │               └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       │           └── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:725
#     │   │       │               ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │               └── stop_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:527
#     │   │       │                   └── stop, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:332
#     │   │       │                       ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │                       └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │                           └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       ├── vescale_zbv_backward_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:1012
#     │   │       │   ├── switch_dtensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:42
#     │   │       │   └── wrap, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:43
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       └── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       ├── vescale_zbv_backward_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:1012
#     │   │       │   ├── switch_dtensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:42
#     │   │       │   └── wrap, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:43
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       └── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       └── vescale_zbv_backward_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:1012
#     │   │           ├── switch_dtensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:42
#     │   │           └── wrap, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:43
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               └── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   └── _collect_microbatch_losses, /root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py:239
#     ├── flush, /root/vescale_prj/veScale/vescale/ndtimeline/api.py:318
#     │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   └── async_flush, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:588
#     │       ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:603
#     │       ├── __new__, /root/vescale_prj/veScale/vescale/ndtimeline/logger.py:24
#     │       ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:615
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   └── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │       └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │           └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       ├── <dictcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:622
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   └── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       ├── _register_timers, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:475
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │       └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │           └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       └── __new__, /root/vescale_prj/veScale/vescale/ndtimeline/logger.py:24
#     ├── wait, /root/vescale_prj/veScale/vescale/ndtimeline/api.py:293
#     │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   └── wait, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:667
#     ├── destroy_pg, /root/vescale_prj/veScale/test/common_dtensor.py:173
#     ├── device_type, /root/vescale_prj/veScale/test/common_dtensor.py:128
#     ├── backend, /root/vescale_prj/veScale/test/common_dtensor.py:137
#     └── __cleanup, /root/vescale_prj/veScale/vescale/checkpoint/api/vescale_checkpointer.py:234
#         ├── clear_cache, /root/vescale_prj/veScale/vescale/checkpoint/planner/vescale/vescale_planner.py:129
#         │   └── clear, /root/vescale_prj/veScale/vescale/checkpoint/planner/common.py:84
#         └── _cleanup_futures, /root/vescale_prj/veScale/vescale/checkpoint/api/base_checkpointer.py:62

# %% [markdown]
# ### Study plan

# %%
import re
from collections import deque

def parse_log_file(file_path):
    with open(file_path, 'r') as f:
        logs = []
        for line in f:
            # Match for function entry logs with '>' or '-->'
            match_push = re.match(r'^(--+>|\s*>)\s*call function (.+?) in (.+?):(\d+)', line)
            if match_push:
                function_name = match_push.group(2)
                file_path = match_push.group(3)
                line_number = int(match_push.group(4))
                logs.append((function_name, file_path, line_number, "push"))
                continue

            # Match for function exit logs with '<' or '<--'
            match_pop = re.match(r'^(<--+|\s*<)\s*exit function (.+?) in (.+?):(\d+)', line)
            if match_pop:
                function_name = match_pop.group(2)
                file_path = match_pop.group(3)
                line_number = int(match_pop.group(4))
                logs.append((function_name, file_path, line_number, "pop"))
                continue

    return logs

class CallStackNode:
    def __init__(self, function_name, file_path, line_number):
        self.function_name = function_name
        self.file_path = file_path
        self.line_number = line_number
        self.children = []
        self.parent = None

    def add_child(self, child_node):
        child_node.parent = self
        self.children.append(child_node)

    def __repr__(self, level=0, is_last_child=True, parent_last_childs=[]):
        indent = ''
        for parent_last in parent_last_childs:
            indent += '    ' if parent_last else '│   '

        branch = '└── ' if is_last_child else '├── '
        repr_str = f"{indent}{branch}{self.function_name}, {self.file_path}:{self.line_number}\n" # complete

        for i, child in enumerate(self.children):
            repr_str += child.__repr__(level + 1, i == len(self.children) - 1, parent_last_childs + [is_last_child])
        return repr_str

class CallStackTree:
    def __init__(self):
        self.root = CallStackNode("root", "", 0)
        self.current_node = self.root

    def push(self, function_name, file_path, line_number):
        new_node = CallStackNode(function_name, file_path, line_number)
        self.current_node.add_child(new_node)
        self.current_node = new_node

    def pop(self):
        if self.current_node != self.root:
            self.current_node = self.current_node.parent

    def breadth_first_traversal(self):
        queue = deque([self.root])
        visited = set()
        traversal_order = []
        while queue:
            current_node = queue.popleft()
            node_id = (current_node.function_name, current_node.file_path, current_node.line_number)
            if node_id not in visited:
                visited.add(node_id)
                traversal_order.append(current_node)
                queue.extend(current_node.children)
        return traversal_order

    def __repr__(self):
        return self.root.__repr__()

# Parse log file and construct call stack tree
log_file_path = "/root/vescale_prj/veScale/test/parallel/pipeline/instruction/logs-test_schedule-host_f78e8e970a17-pid_199624-py/tracing-test_schedule-20240829_071457.log"
logs = parse_log_file(log_file_path)

call_stack_tree = CallStackTree()

for log in logs:
    function_name, file_path, line_number, operation = log
    if operation == "push":
        call_stack_tree.push(function_name, file_path, line_number)
    elif operation == "pop":
        call_stack_tree.pop()

# Print the call stack tree
# print(call_stack_tree)

# Generate breadth-first learning plan without duplicates
traversal_order = call_stack_tree.breadth_first_traversal()
print("\nLearning Plan (Breadth-First, No Duplicates):")
for node in traversal_order:
    if node.function_name != "root":
        print(f"Learn function '{node.function_name}' in file '{node.file_path}', line {node.line_number}.")
# Out:
# Learning Plan (Breadth-First, No Duplicates):
# Learn function 'init_device_mesh' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 48.
# Learn function 'init_ndtimers' in file '/root/vescale_prj/veScale/vescale/ndtimeline/api.py', line 72.
# Learn function '__init__' in file '/root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py', line 164.
# Learn function 'get_global_tensor_parallel_meshes' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 361.
# Learn function 'get_linear_pp_module_dep2' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 291.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py', line 635.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 133.
# Learn function 'execute' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 267.
# Learn function 'flush' in file '/root/vescale_prj/veScale/vescale/ndtimeline/api.py', line 318.
# Learn function 'wait' in file '/root/vescale_prj/veScale/vescale/ndtimeline/api.py', line 293.
# Learn function 'destroy_pg' in file '/root/vescale_prj/veScale/test/common_dtensor.py', line 173.
# Learn function 'device_type' in file '/root/vescale_prj/veScale/test/common_dtensor.py', line 128.
# Learn function 'backend' in file '/root/vescale_prj/veScale/test/common_dtensor.py', line 137.
# Learn function '__cleanup' in file '/root/vescale_prj/veScale/vescale/checkpoint/api/vescale_checkpointer.py', line 234.
# Learn function 'init_device_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 594.
# Learn function 'is_initialized' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 694.
# Learn function 'get_strategy_size' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 261.
# Learn function 'get_tensor_parallel_rank' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 315.
# Learn function 'get_pipeline_parallel_rank' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 290.
# Learn function 'get_data_parallel_rank' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 303.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/handlers/sock_handler.py', line 31.
# Learn function 'is_internal_vescale' in file '/root/vescale_prj/veScale/vescale/ndtimeline/is_internal.py', line 22.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/world_info.py', line 62.
# Learn function '__call__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 686.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 2.
# Learn function 'register_timers' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 458.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py', line 166.
# Learn function 'get' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 135.
# Learn function 'get_tensor_parallel_mesh' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 352.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 224.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 86.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 46.
# Learn function 'get_instruction_list' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 215.
# Learn function 'reset_global_counter' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 53.
# Learn function 'wrap' in file '/root/vescale_prj/veScale/vescale/dtensor/_diff.py', line 59.
# Learn function '_collect_microbatch_losses' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 239.
# Learn function 'async_flush' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 588.
# Learn function 'wait' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 667.
# Learn function 'clear_cache' in file '/root/vescale_prj/veScale/vescale/checkpoint/planner/vescale/vescale_planner.py', line 129.
# Learn function '_cleanup_futures' in file '/root/vescale_prj/veScale/vescale/checkpoint/api/base_checkpointer.py', line 62.
# Learn function 'size' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 447.
# Learn function 'lookup_rank' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 221.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/handlers/handler_base.py', line 25.
# Learn function 'try_to_connect' in file '/root/vescale_prj/veScale/vescale/ndtimeline/handlers/sock_handler.py', line 41.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/world_info.py', line 2.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 411.
# Learn function '<lambda>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 197.
# Learn function '__post_init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 204.
# Learn function '_register_timers' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 475.
# Learn function '__init__' in file '/root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py', line 133.
# Learn function '__getitem__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 426.
# Learn function 'update_vescale_debug_mode_from_env' in file '/root/vescale_prj/veScale/vescale/debug/debug_log.py', line 88.
# Learn function '_get_or_create_default_group' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 313.
# Learn function '_get_device_handle' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 153.
# Learn function '_get_current_device' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 281.
# Learn function 'get_num_chunks' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 263.
# Learn function 'generate_one_forward_mapping' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 160.
# Learn function 'construct_communication_graph' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 110.
# Learn function 'num_stage' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 193.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 603.
# Learn function 'gen_instruction' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 115.
# Learn function 'get_instruction_list' in file '/root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py', line 121.
# Learn function 'execute' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 653.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 603.
# Learn function '__new__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/logger.py', line 24.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 615.
# Learn function '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 622.
# Learn function 'clear' in file '/root/vescale_prj/veScale/vescale/checkpoint/planner/common.py', line 84.
# Learn function 'get_strategy_coordinate' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 188.
# Learn function '__post_init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/world_info.py', line 37.
# Learn function 'init_cuda_dist_associated' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 449.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 227.
# Learn function 'create_child_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 54.
# Learn function 'get_pre_stage' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 211.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/plan/spec.py', line 2.
# Learn function 'is_pipeline_first_stage' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 249.
# Learn function 'get_current_mesh' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 269.
# Learn function '<lambda>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 125.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 2.
# Learn function '<lambda>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 157.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 199.
# Learn function 'get_v_schedule' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 455.
# Learn function 'gen_instruction' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 629.
# Learn function 'get_instruction_list' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 420.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 674.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 675.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 676.
# Learn function 'get_current_model' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 246.
# Learn function 'vescale_zbv_recv_forward' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 728.
# Learn function 'vescale_zbv_forward' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 810.
# Learn function 'vescale_zbv_send_forward' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 703.
# Learn function 'vescale_zbv_recv_post_validation' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 1075.
# Learn function 'vescale_zbv_send_post_validation' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 1080.
# Learn function 'vescale_zbv_post_validation' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 1070.
# Learn function 'vescale_zbv_recv_backward' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 779.
# Learn function 'vescale_zbv_backward_b' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 899.
# Learn function 'vescale_zbv_send_backward' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 756.
# Learn function 'vescale_zbv_backward_w' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 1012.
# Learn function 'copy' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 210.
# Learn function '__le__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 174.
# Learn function 'get_local_rank' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 282.
# Learn function 'init' in file '/root/vescale_prj/veScale/vescale/ndtimeline/pool.py', line 65.
# Learn function '__getitem__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/world_info.py', line 107.
# Learn function 'init' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 61.
# Learn function 'get_rank' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 498.
# Learn function '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 410.
# Learn function 'is_first' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 197.
# Learn function 'is_last' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 204.
# Learn function 'try_v_schedule' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 219.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 478.
# Learn function 'get_id' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 214.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 2.
# Learn function '__hash__' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 2.
# Learn function 'communicate' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 522.
# Learn function '<lambda>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 552.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 565.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 630.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 631.
# Learn function '_set_inst' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 427.
# Learn function 'gen_instruction_str_list' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 642.
# Learn function 'get_recv_comms' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 169.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 746.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 747.
# Learn function 'f' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 734.
# Learn function 'prepare_data' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 851.
# Learn function 'forward' in file '/root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py', line 141.
# Learn function 'get_send_comms' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 141.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 723.
# Learn function 'f' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 711.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 796.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 797.
# Learn function 'f' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 784.
# Learn function 'switch_dtensor' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 42.
# Learn function 'wrap' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 43.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 774.
# Learn function 'f' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 763.
# Learn function '__init__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/pool.py', line 29.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 77.
# Learn function 'calibrate' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 95.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 228.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 229.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 230.
# Learn function 'put' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 249.
# Learn function 'put_w' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 244.
# Learn function 'get_max_stage_bubble' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 236.
# Learn function 'even_breaker' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 545.
# Learn function 'build_from_dict' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 452.
# Learn function 'recv_forward' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 594.
# Learn function 'cross_mesh_recv' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 66.
# Learn function 'maybe_tensor' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 57.
# Learn function 'send_forward' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 684.
# Learn function 'cross_mesh_send' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 95.
# Learn function 'recv_backward' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 639.
# Learn function 'to_tensor' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 45.
# Learn function 'send_backward' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 725.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 114.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 116.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py', line 461.
# Learn function '_mapping_local_rank_to_target_rank_by_device_mesh' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 96.
# Learn function 'ndtimeit_p2p' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 713.
# Learn function '_communicate' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 411.
# Learn function 'ndtimeit_p2p' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 725.
# Learn function 'get_mapping_rank' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 566.
# Learn function '<listcomp>' in file '/root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py', line 75.
# Learn function 'get_nccl_p2p_stream' in file '/root/vescale_prj/veScale/vescale/ndtimeline/stream.py', line 25.
# Learn function 'start_timer' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 510.
# Learn function '_batched_p2p_ops' in file '/root/vescale_prj/veScale/vescale/pipe/p2p_communication.py', line 219.
# Learn function 'stop_timer' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 527.
# Learn function 'start' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 305.
# Learn function 'stop' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 332.
# Learn function '__gt__' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 177.
# Learn function 'getter' in file '/root/vescale_prj/veScale/vescale/ndtimeline/timer.py', line 467.
# Learn function 'get' in file '/root/vescale_prj/veScale/vescale/ndtimeline/pool.py', line 71.
# Learn function 'get' in file '/root/vescale_prj/veScale/vescale/ndtimeline/pool.py', line 44.
