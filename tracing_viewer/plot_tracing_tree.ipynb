# %% [markdown]
# ## Complete tree printing

# %%
import re

def parse_log_file(file_path):
    with open(file_path, 'r') as f:
        logs = []
        for line in f:
            # Match for function entry logs with '>' or '-->'
            match_push = re.match(r'^(--+>|\s*>)\s*call function (.+?) in (.+?):(\d+)', line)
            if match_push:
                function_name = match_push.group(2)
                file_path = match_push.group(3)
                line_number = int(match_push.group(4))
                logs.append((function_name, file_path, line_number, "push"))
                continue

            # Match for function exit logs with '<' or '<--'
            match_pop = re.match(r'^(<--+|\s*<)\s*exit function (.+?) in (.+?):(\d+)', line)
            if match_pop:
                function_name = match_pop.group(2)
                file_path = match_pop.group(3)
                line_number = int(match_pop.group(4))
                logs.append((function_name, file_path, line_number, "pop"))
                continue

    return logs

class CallStackNode:
    def __init__(self, function_name, file_path, line_number):
        self.function_name = function_name
        self.file_path = file_path
        self.line_number = line_number
        self.children = []
        self.parent = None

    def add_child(self, child_node):
        child_node.parent = self
        self.children.append(child_node)

    def __repr__(self, level=0, is_last_child=True, parent_last_childs=[]):
        indent = ''
        for parent_last in parent_last_childs:
            indent += '    ' if parent_last else '│   '

        branch = '└── ' if is_last_child else '├── '
        repr_str = f"{indent}{branch}{self.function_name}, {self.file_path}:{self.line_number}\n" # complete
        # repr_str = f"{indent}{branch}{self.function_name}\n" # simple without file path and line number

        for i, child in enumerate(self.children):
            repr_str += child.__repr__(level + 1, i == len(self.children) - 1, parent_last_childs + [is_last_child])
        return repr_str

class CallStackTree:
    def __init__(self):
        self.root = CallStackNode("root", "", 0)
        self.current_node = self.root

    def push(self, function_name, file_path, line_number):
        new_node = CallStackNode(function_name, file_path, line_number)
        self.current_node.add_child(new_node)
        self.current_node = new_node

    def pop(self):
        if self.current_node != self.root:
            self.current_node = self.current_node.parent

    def __repr__(self):
        return self.root.__repr__()

# Parse log file and construct call stack tree
log_file_path = "/root/vescale_prj/veScale/test/parallel/pipeline/instruction/logs-test_schedule-host_f78e8e970a17-pid_199624-py/tracing-test_schedule-20240829_071457.log"
logs = parse_log_file(log_file_path)

call_stack_tree = CallStackTree()

for log in logs:
    function_name, file_path, line_number, operation = log
    if operation == "push":
        call_stack_tree.push(function_name, file_path, line_number)
    elif operation == "pop":
        call_stack_tree.pop()

print(call_stack_tree)
# Out:
# └── root, :0
#     ├── init_device_mesh, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:48
#     │   └── init_device_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:594
#     │       └── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │           ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │           ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │           │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │           ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │           ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │           ├── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │           └── _init_process_groups, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:364
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │               └── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     ├── init_ndtimers, /root/vescale_prj/veScale/vescale/ndtimeline/api.py:72
#     │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   ├── get_strategy_size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:261
#     │   │   └── size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:447
#     │   │       └── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_strategy_size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:261
#     │   │   └── size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:447
#     │   │       └── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_strategy_size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:261
#     │   │   └── size, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:447
#     │   │       └── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_tensor_parallel_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:315
#     │   │   └── lookup_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:221
#     │   │       └── get_strategy_coordinate, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:188
#     │   │           ├── get_local_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:282
#     │   │           └── get_strategy_coordinate, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:188
#     │   │               └── <listcomp>, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:218
#     │   ├── get_pipeline_parallel_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:290
#     │   │   └── lookup_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:221
#     │   ├── get_data_parallel_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:303
#     │   │   └── lookup_rank, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:221
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/handlers/sock_handler.py:31
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/handlers/handler_base.py:25
#     │   │   └── try_to_connect, /root/vescale_prj/veScale/vescale/ndtimeline/handlers/sock_handler.py:41
#     │   ├── is_internal_vescale, /root/vescale_prj/veScale/vescale/ndtimeline/is_internal.py:22
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:62
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:2
#     │   │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:37
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:2
#     │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:53
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:411
#     │   │       └── init_cuda_dist_associated, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:449
#     │   │           ├── init, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:65
#     │   │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:29
#     │   │           ├── __getitem__, /root/vescale_prj/veScale/vescale/ndtimeline/world_info.py:107
#     │   │           └── init, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:61
#     │   │               ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:77
#     │   │               └── calibrate, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:95
#     │   │                   ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:114
#     │   │                   ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:116
#     │   │                   └── __new__, /root/vescale_prj/veScale/vescale/ndtimeline/logger.py:24
#     │   ├── is_internal_vescale, /root/vescale_prj/veScale/vescale/ndtimeline/is_internal.py:22
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │   │   ├── <lambda>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:197
#     │   │   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   └── register_timers, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:458
#     │       └── _register_timers, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:475
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │           │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │           │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │           └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │               └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │                   └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:164
#     │   └── <listcomp>, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:166
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       ├── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     │       └── __init__, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:133
#     ├── get_global_tensor_parallel_meshes, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:361
#     │   ├── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   ├── get_tensor_parallel_mesh, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:352
#     │   │   ├── get, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:135
#     │   │   └── __getitem__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:426
#     │   │       └── create_child_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:54
#     │   │           ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │           │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │           │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │           │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │           │   ├── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   │           │   └── _validate_mesh, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:339
#     │   │           └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:410
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │   │   ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │   │   ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │   │   │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │   │   └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:224
#     │       ├── update_vescale_debug_mode_from_env, /root/vescale_prj/veScale/vescale/debug/debug_log.py:88
#     │       ├── _get_or_create_default_group, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:313
#     │       │   └── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │       ├── _get_device_handle, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:153
#     │       └── _get_current_device, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:281
#     ├── get_linear_pp_module_dep2, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:291
#     │   └── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:86
#     │       ├── get_num_chunks, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:263
#     │       ├── generate_one_forward_mapping, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:160
#     │       │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   ├── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │       │   │   ├── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   │   ├── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   │   ├── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   │   └── is_last, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │   │   └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │       └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │   │   └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │       └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   ├── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │   │   └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │       └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │   │   └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/plan/spec.py:2
#     │       │   └── is_pipeline_first_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:249
#     │       │       └── get_pre_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:211
#     │       │           └── is_first, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:197
#     │       └── construct_communication_graph, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:110
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── get_current_mesh, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:269
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:125
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           ├── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     │           ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │           ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:2
#     │           └── <lambda>, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:157
#     ├── get_global_tensor_parallel_meshes, /root/vescale_prj/veScale/vescale/devicemesh_api/api.py:361
#     ├── <listcomp>, /root/vescale_prj/veScale/test/parallel/pipeline/instruction/test_schedule.py:635
#     ├── __init__, /root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py:133
#     │   ├── __init__, /root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py:46
#     │   │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │   │   ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:603
#     │   │   │   ├── num_stage, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:193
#     │   │   │   ├── __init__, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:199
#     │   │   │   └── get_v_schedule, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:455
#     │   │   │       ├── try_v_schedule, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:219
#     │   │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:228
#     │   │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:229
#     │   │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:230
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │   └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:244
#     │   │   │       │   │   └── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │       ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   │       └── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
#     │   │   │       │   ├── put, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:249
#     │   │   │       │   │   ├── get_id, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:214
# ...
#     │   │       │       │   ├── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:713
#     │   │       │       │   │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   │       │       │   │   ├── get_nccl_p2p_stream, /root/vescale_prj/veScale/vescale/ndtimeline/stream.py:25
#     │   │       │       │   │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │       │   │   └── start_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:510
#     │   │       │       │   │       └── start, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:305
#     │   │       │       │   │           ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │       │   │           ├── getter, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:467
#     │   │       │       │   │           └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │       │   │               └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       │       │   ├── _communicate, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:411
#     │   │       │       │   │   ├── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   │       │       │   │   ├── _mapping_local_rank_to_target_rank_by_device_mesh, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:96
#     │   │       │       │   │   ├── _mapping_local_rank_to_target_rank_by_device_mesh, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:96
#     │   │       │       │   │   └── _batched_p2p_ops, /root/vescale_prj/veScale/vescale/pipe/p2p_communication.py:219
#     │   │       │       │   └── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:725
#     │   │       │       │       ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │       │       └── stop_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:527
#     │   │       │       │           └── stop, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:332
#     │   │       │       │               ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │       │               └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │       │                   └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       │       └── cross_mesh_send, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:95
#     │   │       │           ├── get_mapping_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:566
#     │   │       │           │   └── get_rank, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:498
#     │   │       │           ├── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:713
#     │   │       │           │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   │       │           │   ├── get_nccl_p2p_stream, /root/vescale_prj/veScale/vescale/ndtimeline/stream.py:25
#     │   │       │           │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │           │   └── start_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:510
#     │   │       │           │       └── start, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:305
#     │   │       │           │           ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │           │           ├── getter, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:467
#     │   │       │           │           └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │           │               └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       │           └── ndtimeit_p2p, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:725
#     │   │       │               ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   │       │               └── stop_timer, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:527
#     │   │       │                   └── stop, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:332
#     │   │       │                       ├── __gt__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:177
#     │   │       │                       └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:71
#     │   │       │                           └── get, /root/vescale_prj/veScale/vescale/ndtimeline/pool.py:44
#     │   │       ├── vescale_zbv_backward_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:1012
#     │   │       │   ├── switch_dtensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:42
#     │   │       │   └── wrap, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:43
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       └── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       ├── vescale_zbv_backward_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:1012
#     │   │       │   ├── switch_dtensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:42
#     │   │       │   └── wrap, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:43
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       │       └── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │       └── vescale_zbv_backward_w, /root/vescale_prj/veScale/vescale/pipe/_schedules/zero_bubble_v.py:1012
#     │   │           ├── switch_dtensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:42
#     │   │           └── wrap, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:43
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               ├── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   │               └── to_tensor, /root/vescale_prj/veScale/vescale/pipe/_schedules/instruction_base.py:45
#     │   └── _collect_microbatch_losses, /root/vescale_prj/veScale/vescale/pipe/pipe_emmiter.py:239
#     ├── flush, /root/vescale_prj/veScale/vescale/ndtimeline/api.py:318
#     │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   └── async_flush, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:588
#     │       ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:603
#     │       ├── __new__, /root/vescale_prj/veScale/vescale/ndtimeline/logger.py:24
#     │       ├── <listcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:615
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   └── copy, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:210
#     │       │       └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │           └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       ├── <dictcomp>, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:622
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   ├── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       │   └── __le__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:174
#     │       ├── _register_timers, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:475
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   ├── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       │   └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:227
#     │       │       └── __init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:2
#     │       │           └── __post_init__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:204
#     │       └── __new__, /root/vescale_prj/veScale/vescale/ndtimeline/logger.py:24
#     ├── wait, /root/vescale_prj/veScale/vescale/ndtimeline/api.py:293
#     │   ├── is_initialized, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:694
#     │   ├── __call__, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:686
#     │   └── wait, /root/vescale_prj/veScale/vescale/ndtimeline/timer.py:667
#     ├── destroy_pg, /root/vescale_prj/veScale/test/common_dtensor.py:173
#     ├── device_type, /root/vescale_prj/veScale/test/common_dtensor.py:128
#     ├── backend, /root/vescale_prj/veScale/test/common_dtensor.py:137
#     └── __cleanup, /root/vescale_prj/veScale/vescale/checkpoint/api/vescale_checkpointer.py:234
#         ├── clear_cache, /root/vescale_prj/veScale/vescale/checkpoint/planner/vescale/vescale_planner.py:129
#         │   └── clear, /root/vescale_prj/veScale/vescale/checkpoint/planner/common.py:84
#         └── _cleanup_futures, /root/vescale_prj/veScale/vescale/checkpoint/api/base_checkpointer.py:62

# %% [markdown]
# ### Study plan

# %%
import re
import os
from collections import deque

def parse_log_file(file_path):
    with open(file_path, 'r') as f:
        logs = []
        for line in f:
            # Match for function entry logs with '>' or '-->'
            match_push = re.match(r'^(--+>|\s*>)\s*call function (.+?) in (.+?):(\d+)', line)
            if match_push:
                function_name = match_push.group(2)
                file_path = match_push.group(3)
                line_number = int(match_push.group(4))
                logs.append((function_name, file_path, line_number, "push"))
                continue

            # Match for function exit logs with '<' or '<--'
            match_pop = re.match(r'^(<--+|\s*<)\s*exit function (.+?) in (.+?):(\d+)', line)
            if match_pop:
                function_name = match_pop.group(2)
                file_path = match_pop.group(3)
                line_number = int(match_pop.group(4))
                logs.append((function_name, file_path, line_number, "pop"))
                continue

    return logs

class CallStackNode:
    def __init__(self, function_name, file_path, line_number):
        self.function_name = function_name
        self.file_path = file_path
        self.line_number = line_number
        self.children = []
        self.parent = None

    def add_child(self, child_node):
        child_node.parent = self
        self.children.append(child_node)

    def __repr__(self, level=0, is_last_child=True, parent_last_childs=[]):
        indent = ''
        for parent_last in parent_last_childs:
            indent += '    ' if parent_last else '│   '

        branch = '└── ' if is_last_child else '├── '
        repr_str = f"{indent}{branch}{self.function_name}, {self.file_path}:{self.line_number}\n" # complete

        for i, child in enumerate(self.children):
            repr_str += child.__repr__(level + 1, i == len(self.children) - 1, parent_last_childs + [is_last_child])
        return repr_str

class CallStackTree:
    def __init__(self):
        self.root = CallStackNode("root", "", 0)
        self.current_node = self.root

    def push(self, function_name, file_path, line_number):
        new_node = CallStackNode(function_name, file_path, line_number)
        self.current_node.add_child(new_node)
        self.current_node = new_node

    def pop(self):
        if self.current_node != self.root:
            self.current_node = self.current_node.parent

    def breadth_first_traversal(self):
        queue = deque([self.root])
        visited = set()
        traversal_order = []
        while queue:
            current_node = queue.popleft()
            node_id = (current_node.function_name, current_node.file_path, current_node.line_number)
            if node_id not in visited:
                visited.add(node_id)
                traversal_order.append(current_node)
                queue.extend(current_node.children)
        return traversal_order

    def depth_first_traversal(self):
        stack = [self.root]
        visited = set()
        traversal_order = []

        while stack:
            current_node = stack.pop()
            node_id = (current_node.function_name, current_node.file_path, current_node.line_number)

            if node_id not in visited:
                visited.add(node_id)
                traversal_order.append(current_node)

                # Extend stack with children in reverse order to preserve depth-first traversal
                stack.extend(reversed(current_node.children))

        return traversal_order

    def build_bfs_tree(self):
        bfs_order = self.breadth_first_traversal()
        bfs_tree_root = CallStackNode("BFS Root", "", 0)
        node_mapping = {bfs_order[0]: bfs_tree_root}  # Map original root to new BFS tree root

        for node in bfs_order[1:]:
            parent = node.parent
            if parent in node_mapping:
                new_node = CallStackNode(node.function_name, node.file_path, node.line_number)
                node_mapping[parent].add_child(new_node)
                node_mapping[node] = new_node

        return bfs_tree_root

    def __repr__(self):
        return self.root.__repr__()

# Parse log file and construct call stack tree
log_file_path = "/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/logs/2024_0911_1938_40/logs-finetune_4D-host_d3cb3edeb6a9-pid_432289-py/tracing-finetune_4D-2024_0911_1938_40.log"
logs = parse_log_file(log_file_path)

call_stack_tree = CallStackTree()

for log in logs:
    function_name, file_path, line_number, operation = log
    if operation == "push":
        call_stack_tree.push(function_name, file_path, line_number)
    elif operation == "pop":
        call_stack_tree.pop()

# Ensure the logs directory exists
logs_dir = "logs"
if not os.path.exists(logs_dir):
    os.makedirs(logs_dir)

# Save and print Breadth-First Traversal
bfs_log_file = os.path.join(logs_dir, "bfs_traversal.log")
traversal_order = call_stack_tree.breadth_first_traversal()

print("\nLearning Plan (Breadth-First, No Duplicates):")
with open(bfs_log_file, 'w') as f:
    f.write("Learning Plan (Breadth-First, No Duplicates):\n")
    for node in traversal_order:
        if node.function_name != "root":
            output = f"'{node.function_name}' in file '{node.file_path}', line {node.line_number}."
            print(output)
            f.write(output + "\n")

# Save and print Depth-First Traversal
dfs_log_file = os.path.join(logs_dir, "dfs_traversal.log")
traversal_order = call_stack_tree.depth_first_traversal()

print("\nLearning Plan (Depth-First, No Duplicates):")
with open(dfs_log_file, 'w') as f:
    f.write("Learning Plan (Depth-First, No Duplicates):\n")
    for node in traversal_order:
        if node.function_name != "root":
            output = f"'{node.function_name}' in file '{node.file_path}', line {node.line_number}."
            print(output)
            f.write(output + "\n")

################################################################################
# ### Save and print Tree Representation (all log lines, long time to process)
# tree_log_file = os.path.join(logs_dir, "call_stack_tree.log")
# with open(tree_log_file, 'w') as f:
#     tree_repr = repr(call_stack_tree)
#     f.write(tree_repr)
#     print(tree_repr)
################################################################################

print(f"Breadth-First traversal saved to {bfs_log_file}")
print(f"Depth-First traversal saved to {dfs_log_file}")
# print(f"Call stack tree representation saved to {tree_log_file}")

################################################################################

# BFS Summary
bfs_summary = f"\n{len(traversal_order)} function calls processed."
with open(bfs_log_file, 'a') as f:
    f.write(bfs_summary)
print(bfs_summary)

# Build BFS Tree from traversal
bfs_tree_root = call_stack_tree.build_bfs_tree()

# Save and print BFS Tree Representation
bfs_tree_log_file = os.path.join(logs_dir, "bfs_tree.log")
with open(bfs_tree_log_file, 'w') as f:
    bfs_tree_repr = bfs_tree_root.__repr__()
    f.write(bfs_tree_repr)
    print(bfs_tree_repr)

print(f"Breadth-First tree representation saved to {bfs_tree_log_file}")
# Out:
# Learning Plan (Breadth-First, No Duplicates):
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 633.
# '<module>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 1.
# '<dictcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 635.
# 'main' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 234.
# '__cleanup' in file '/root/vescale_prj/veScale/vescale/checkpoint/api/vescale_checkpointer.py', line 234.
# 'init_device_mesh' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 48.
# 'get' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 135.
# 'manual_seed' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 62.
# 'from_pretrained' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 247.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 400.
# '__getitem__' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 399.
# 'parallelize_module' in file '/root/vescale_prj/veScale/vescale/dmodule/api.py', line 74.
# '__init__' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 67.
# 'configure_optimizers' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 416.
# 'get_batch' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 304.
# '_get_param_groups' in file '/root/vescale_prj/veScale/vescale/optim/base_optimizer.py', line 103.
# 'estimate_loss' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 457.
# 'zero_grad_buffer' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 278.
# 'forward' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 184.
# '__torch_dispatch__' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 371.
# 'finish_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 263.
# 'step' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1234.
# 'zero_grad' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 882.
# 'to_local' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 490.
# 'clear_cache' in file '/root/vescale_prj/veScale/vescale/checkpoint/planner/vescale/vescale_planner.py', line 129.
# '_cleanup_futures' in file '/root/vescale_prj/veScale/vescale/checkpoint/api/base_checkpointer.py', line 62.
# 'init_device_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 594.
# '_get_device_handle' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 153.
# 'init_vescale_rng_tracker' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 30.
# 'get_coordinate' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 533.
# '_manual_seed' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 181.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 252.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 2.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 157.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 280.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 308.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 309.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 323.
# '__getitem__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 426.
# 'update_vescale_debug_mode_from_env' in file '/root/vescale_prj/veScale/vescale/debug/debug_log.py', line 88.
# 'is_dmodule' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 109.
# 'check_and_sanitize_sharding_plan' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 88.
# 'initialize_attributes' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 119.
# 'initialize_methods' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 477.
# 'register_sharding_plan' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 174.
# 'init_parameters' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 311.
# 'init_forward' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 349.
# 'init_backward' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 392.
# 'post_patch_submodules' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 420.
# 'prepare_factory' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 430.
# 'set_dmodule' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 113.
# 'get_dim_groups' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 472.
# '__init__' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 244.
# '_make_param_hook' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 190.
# '<dictcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 418.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 421.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 422.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 427.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 428.
# '__init__' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 178.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 315.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 316.
# 'distribute_tensor' in file '/root/vescale_prj/veScale/vescale/dtensor/api.py', line 154.
# 'reset' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 424.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 209.
# 'operator_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 377.
# 'finish_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 449.
# '_copy_model_grads_to_main_grads' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1142.
# 'clip_grad_norm' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1223.
# '_copy_main_params_to_model_params' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1170.
# '_dispatch_gather_model_params' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 959.
# '_zero_grad_group_helper' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 23.
# 'forward' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 204.
# 'clear' in file '/root/vescale_prj/veScale/vescale/checkpoint/planner/common.py', line 84.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 224.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 391.
# 'set_seed' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 158.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 168.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 45.
# '_init_weights' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 201.
# 'get_num_params' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 189.
# 'create_child_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 54.
# 'has_all_attributes' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 149.
# '<lambda>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 195.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 228.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 233.
# '_distribute_parameter' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 257.
# 'requires_grad_' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 523.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 2.
# 'ndim' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 486.
# 'get_fwd_plan' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 513.
# 'get_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 173.
# 'get_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 254.
# 'make_backward_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 402.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/__init__.py', line 1.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/__init__.py', line 1.
# 'get_all_model_patch' in file '/root/vescale_prj/veScale/vescale/model/patch/__init__.py', line 23.
# 'patch' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 57.
# 'patch' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py', line 82.
# 'patch' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 181.
# 'get_param_nelements' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 19.
# '_pad_if_needed' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 274.
# '_get' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 413.
# '_set_bucket' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 379.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 198.
# '__init__' in file '/root/vescale_prj/veScale/vescale/optim/base_optimizer.py', line 81.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 219.
# 'device_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 404.
# 'placements' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 413.
# 'compute_local_shape_and_global_offset' in file '/root/vescale_prj/veScale/vescale/dtensor/_utils.py', line 51.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 279.
# 'build_model_gbuf_range_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 518.
# 'build_model_param_gbuf_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 534.
# 'build_optimizer_group_ranges' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 550.
# 'build_model_and_main_param_groups' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 601.
# 'get_model_param_buffer_dp_views' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 925.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 377.
# 'is_rng_supported_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 37.
# 'normalize_placements' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 47.
# 'is_interleaved_shard' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 30.
# 'is_shard' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 24.
# 'is_replicate' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 36.
# '_replicate_tensor' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 180.
# '__new__' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 276.
# 'reset' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 75.
# '_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 96.
# '_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 229.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 139.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 50.
# '_bypass_for_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py', line 161.
# '_pre_patch_for_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 193.
# '_operator_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 235.
# '_post_patch_for_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 201.
# 'finish_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 150.
# 'copy_group_grads' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1152.
# 'get_parameters' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1263.
# 'get_main_grads_for_grad_norm' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1270.
# 'clip_grad_norm_fp32' in file '/root/vescale_prj/veScale/vescale/optim/clip_grads.py', line 21.
# 'copy_group_params' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1180.
# '_copy_params_from_param_buffer' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1078.
# '_get_or_create_default_group' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 313.
# '_get_current_device' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 281.
# '_validate_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 339.
# '_init_process_groups' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 364.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 174.
# 'rng_states' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 136.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 132.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 196.
# 'get_rank' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 498.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 410.
# '_normalize_one_placements' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 158.
# 'is_deferred' in file '/root/vescale_prj/veScale/vescale/initialize/deferred_init.py', line 61.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 1.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py', line 1.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 1.
# 'is_partial' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 39.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 114.
# 'is_patched' in file '/root/vescale_prj/veScale/vescale/model/patch/utils.py', line 25.
# 'make_new_row_parallel_linear_forward' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 32.
# 'set_patched' in file '/root/vescale_prj/veScale/vescale/model/patch/utils.py', line 29.
# '__init__' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 45.
# 'size' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 483.
# '_local_shard_size_on_dim' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 169.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 280.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 526.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 581.
# 'shard_buffer_among_dp_world' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 920.
# 'mesh_broadcast' in file '/root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py', line 231.
# '_dispatch_torch_make_wrapper_subclass' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 250.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 2.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 130.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 131.
# '_convert' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 214.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 84.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 123.
# 'apply' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py', line 44.
# 'failed_on_mqa' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 145.
# 'apply' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 49.
# 'unwrap_to_op_info' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 51.
# 'propagate' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 154.
# 'is_replicated' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 553.
# '_is_inplace_op' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 37.
# '_is_out_variant_op' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 44.
# 'wrap' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 194.
# 'defer_resharding' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 134.
# 'start_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 114.
# 'get_model_param_range_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 738.
# 'param_is_shared' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 62.
# 'param_is_sharded_or_replicate_on_first_rank' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 38.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 124.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 55.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 116.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 164.
# 'from_placements' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 40.
# 'is_none' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 54.
# 'normalize_placements' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 46.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/utils.py', line 1.
# 'RowParallelLinear' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 56.
# 'VocabParallelEmbedding' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py', line 38.
# '_VocabParallelCrossEntropy' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 43.
# 'VocabParallelCrossEntropy' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 149.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 187.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 527.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 923.
# '<lambda>' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 98.
# '_convert_by_pi' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 44.
# 'forward' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 48.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 2.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 158.
# 'propagate_op_sharding_non_cached' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 165.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 557.
# 'to_dt' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 195.
# '_enable_autoresharding' in file '/root/vescale_prj/veScale/vescale/dtensor/_diff.py', line 118.
# 'shard_buffer' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 86.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 45.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 47.
# '__eq__' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 2.
# 'build_model_gbuf_range' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 454.
# '_convert' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 77.
# 'redistribute' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 505.
# '__post_init__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 133.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 167.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 174.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 406.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 195.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 196.
# 'pointwise_strategy' in file '/root/vescale_prj/veScale/vescale/dtensor/ops/pointwise_ops.py', line 411.
# '_select_strategy' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 390.
# 'args_spec' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 98.
# 'return_type_tuple_tensors' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 153.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 92.
# '__init__' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 32.
# 'build_param_sharding_info_for_checkpoint' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 383.
# 'build_model_gbuf_param_range_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 399.
# '__len__' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 43.
# 'forward' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 457.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 137.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 409.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 227.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 381.
# 'spec_to_strategy' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 170.
# 'is_partial' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 559.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/ops/pointwise_ops.py', line 441.
# 'max_num_shards' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 355.
# 'output_shape' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 361.
# 'infer_broadcast_dims_map' in file '/root/vescale_prj/veScale/vescale/dtensor/ops/utils.py', line 196.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 346.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 107.
# 'normalize' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 37.
# '__eq__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 209.
# 'redistribute_local_tensor' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 222.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 359.
# 'shape' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 442.
# '__eq__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 417.
# '_decompose_reshard' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 50.
# '_replicate_then_shard' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 34.
# '_reshard_to_replicate_with_pad_one_dim' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 90.
# 'num_shards' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 454.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 106.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 113.
# 'mesh_all_gather' in file '/root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py', line 309.
#
# Learning Plan (Depth-First, No Duplicates):
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 633.
# '<module>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 1.
# '<dictcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 635.
# 'main' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 234.
# 'init_device_mesh' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 48.
# 'init_device_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 594.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 224.
# 'update_vescale_debug_mode_from_env' in file '/root/vescale_prj/veScale/vescale/debug/debug_log.py', line 88.
# '_get_or_create_default_group' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 313.
# '_get_device_handle' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 153.
# '_get_current_device' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 281.
# '_validate_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 339.
# '_init_process_groups' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 364.
# 'get_rank' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 498.
# 'get' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 135.
# 'manual_seed' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 62.
# 'init_vescale_rng_tracker' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 30.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 391.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 174.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 124.
# 'rng_states' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 136.
# 'get_coordinate' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 533.
# '_manual_seed' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 181.
# 'set_seed' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 158.
# 'from_pretrained' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 247.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 252.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 2.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 157.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 168.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 132.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 45.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 55.
# '__init__' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 116.
# '_init_weights' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 201.
# 'get_num_params' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 189.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 196.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 280.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 308.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 309.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 323.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 400.
# '__getitem__' in file '/root/vescale_prj/veScale/vescale/devicemesh_api/api.py', line 399.
# '__getitem__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 426.
# 'create_child_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 54.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 410.
# 'parallelize_module' in file '/root/vescale_prj/veScale/vescale/dmodule/api.py', line 74.
# 'is_dmodule' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 109.
# 'check_and_sanitize_sharding_plan' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 88.
# 'initialize_attributes' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 119.
# 'initialize_methods' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 477.
# 'register_sharding_plan' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 174.
# 'has_all_attributes' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 149.
# '<lambda>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 195.
# 'ndim' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 486.
# '_normalize_one_placements' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 158.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 164.
# 'from_placements' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 40.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 2.
# 'is_none' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 54.
# '__eq__' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 2.
# 'normalize_placements' in file '/root/vescale_prj/veScale/vescale/dmodule/placements_interface.py', line 46.
# 'normalize_placements' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 47.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 228.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 233.
# 'init_parameters' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 311.
# '_distribute_parameter' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 257.
# 'is_deferred' in file '/root/vescale_prj/veScale/vescale/initialize/deferred_init.py', line 61.
# 'distribute_tensor' in file '/root/vescale_prj/veScale/vescale/dtensor/api.py', line 154.
# 'is_rng_supported_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/random.py', line 37.
# 'is_interleaved_shard' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 30.
# 'is_shard' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 24.
# '_scatter_tensor_by_shard' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 156.
# 'size' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 483.
# '_split_tensor' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 69.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 124.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 126.
# 'mesh_scatter' in file '/root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py', line 44.
# 'get_dim_groups' in file '/root/vescale_prj/veScale/vescale/dtensor/device_mesh.py', line 472.
# '__new__' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 276.
# '_dispatch_torch_make_wrapper_subclass' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 250.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 2.
# '__torch_dispatch__' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 371.
# 'operator_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 377.
# '_bypass_for_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py', line 161.
# 'apply' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py', line 44.
# '_pre_patch_for_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 193.
# 'failed_on_mqa' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 145.
# 'apply' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 49.
# '_operator_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 235.
# 'unwrap_to_op_info' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 51.
# 'device_mesh' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 404.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 2.
# '__post_init__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 133.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 137.
# 'propagate' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 154.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 158.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 167.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 406.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 409.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 204.
# '__hash__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 381.
# 'propagate_op_sharding_non_cached' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 165.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 195.
# 'spec_to_strategy' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 170.
# '__init__' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 346.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 196.
# 'default_strategy' in file '/root/vescale_prj/veScale/vescale/dtensor/ops/tensor_ops.py', line 52.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/ops/tensor_ops.py', line 71.
# '_select_strategy' in file '/root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py', line 390.
# 'args_spec' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 98.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 107.
# 'return_type_tuple_tensors' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 153.
# 'is_replicated' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 553.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 557.
# 'is_replicate' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 36.
# '_is_inplace_op' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 37.
# '_is_out_variant_op' in file '/root/vescale_prj/veScale/vescale/dtensor/op_schema.py', line 44.
# 'wrap' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 194.
# 'to_dt' in file '/root/vescale_prj/veScale/vescale/dtensor/dispatch.py', line 195.
# '_post_patch_for_dispatch' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 201.
# 'defer_resharding' in file '/root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py', line 134.
# '_enable_autoresharding' in file '/root/vescale_prj/veScale/vescale/dtensor/_diff.py', line 118.
# 'requires_grad_' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 523.
# 'init_forward' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 349.
# 'get_fwd_plan' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 513.
# 'get_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 173.
# 'get_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 254.
# 'init_backward' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 392.
# 'make_backward_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 402.
# 'post_patch_submodules' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 420.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/__init__.py', line 1.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/__init__.py', line 1.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 1.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/utils.py', line 1.
# 'RowParallelLinear' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 56.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py', line 1.
# 'VocabParallelEmbedding' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py', line 38.
# '<module>' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 1.
# '_VocabParallelCrossEntropy' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 43.
# 'VocabParallelCrossEntropy' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 149.
# 'get_all_model_patch' in file '/root/vescale_prj/veScale/vescale/model/patch/__init__.py', line 23.
# 'patch' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 57.
# 'placements' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 413.
# 'is_partial' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 39.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 114.
# 'is_patched' in file '/root/vescale_prj/veScale/vescale/model/patch/utils.py', line 25.
# 'make_new_row_parallel_linear_forward' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 32.
# 'set_patched' in file '/root/vescale_prj/veScale/vescale/model/patch/utils.py', line 29.
# 'patch' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_embedding.py', line 82.
# 'patch' in file '/root/vescale_prj/veScale/vescale/model/patch/vp_cross_entropy.py', line 181.
# 'prepare_factory' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 430.
# 'set_dmodule' in file '/root/vescale_prj/veScale/vescale/dmodule/_dmodule.py', line 113.
# '__init__' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 67.
# '__init__' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 244.
# 'get_param_nelements' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 19.
# '_pad_if_needed' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 274.
# '_get' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 413.
# '_set_bucket' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 379.
# '__init__' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 45.
# 'reset' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 75.
# '_make_param_hook' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 190.
# 'configure_optimizers' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 416.
# '<dictcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 418.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 421.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 422.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 427.
# '<genexpr>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 428.
# '__init__' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 178.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 198.
# '__init__' in file '/root/vescale_prj/veScale/vescale/optim/base_optimizer.py', line 81.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 219.
# 'compute_local_shape_and_global_offset' in file '/root/vescale_prj/veScale/vescale/dtensor/_utils.py', line 51.
# '_local_shard_size_on_dim' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 169.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 187.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 279.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 280.
# 'build_model_gbuf_range_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 518.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 526.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 527.
# 'build_model_gbuf_range' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 454.
# '__init__' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 32.
# 'build_param_sharding_info_for_checkpoint' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 383.
# 'build_model_gbuf_param_range_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 399.
# 'normalize' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 37.
# '__len__' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 43.
# 'build_model_param_gbuf_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 534.
# 'build_optimizer_group_ranges' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 550.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 581.
# 'build_model_and_main_param_groups' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 601.
# 'get_model_param_buffer_dp_views' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 925.
# 'shard_buffer_among_dp_world' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 920.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 923.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 377.
# 'get_batch' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 304.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 315.
# '<listcomp>' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 316.
# '_get_param_groups' in file '/root/vescale_prj/veScale/vescale/optim/base_optimizer.py', line 103.
# 'estimate_loss' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py', line 457.
# 'forward' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 184.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 209.
# '_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 96.
# 'get_sig' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 71.
# '<genexpr>' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 130.
# '<lambda>' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 98.
# '_convert' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 77.
# '_convert_by_pi' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 44.
# 'redistribute' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 505.
# 'forward' in file '/root/vescale_prj/veScale/vescale/dtensor/redistribute.py', line 457.
# '__eq__' in file '/root/vescale_prj/veScale/vescale/dtensor/placement_types.py', line 231.
# '<dictcomp>' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 131.
# '_hook' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 229.
# '_convert' in file '/root/vescale_prj/veScale/vescale/dmodule/_hook.py', line 214.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 139.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 50.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 84.
# 'forward' in file '/root/vescale_prj/veScale/vescale/model/patch/linear.py', line 48.
# 'forward' in file '/root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py', line 123.
# 'to_local' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 490.
# 'forward' in file '/root/vescale_prj/veScale/vescale/dtensor/dtensor.py', line 204.
# 'zero_grad_buffer' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 278.
# 'reset' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 424.
# 'finish_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py', line 263.
# 'finish_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 449.
# 'finish_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 150.
# 'start_grad_sync' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 114.
# 'shard_buffer' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 86.
# '<listcomp>' in file '/root/vescale_prj/veScale/vescale/ddp/grad_buffer.py', line 92.
# 'step' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1234.
# '_copy_model_grads_to_main_grads' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1142.
# 'copy_group_grads' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1152.
# 'get_model_param_range_map' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 738.
# 'clip_grad_norm' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1223.
# 'get_parameters' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1263.
# 'get_main_grads_for_grad_norm' in file '/root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py', line 1270.
# 'param_is_shared' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 62.
# 'param_is_sharded_or_replicate_on_first_rank' in file '/root/vescale_prj/veScale/vescale/optim/utils.py', line 38.
# ...
#     │   │   ├── <genexpr>, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:428
#     │   │   └── __init__, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:178
#     │   │       ├── <genexpr>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:198
#     │   │       ├── __init__, /root/vescale_prj/veScale/vescale/optim/base_optimizer.py:81
#     │   │       ├── <genexpr>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:219
#     │   │       ├── device_mesh, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:404
#     │   │       ├── placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:413
#     │   │       ├── compute_local_shape_and_global_offset, /root/vescale_prj/veScale/vescale/dtensor/_utils.py:51
#     │   │       │   ├── size, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:483
#     │   │       │   └── _local_shard_size_on_dim, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:169
#     │   │       │       └── <listcomp>, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:187
#     │   │       ├── <dictcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:279
#     │   │       │   └── <listcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:280
#     │   │       ├── build_model_gbuf_range_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:518
#     │   │       │   └── <dictcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:526
#     │   │       │       └── <listcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:527
#     │   │       │           └── build_model_gbuf_range, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:454
#     │   │       │               ├── __init__, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:32
#     │   │       │               ├── build_param_sharding_info_for_checkpoint, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:383
#     │   │       │               ├── build_model_gbuf_param_range_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:399
#     │   │       │               │   └── normalize, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:37
#     │   │       │               └── __len__, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:43
#     │   │       ├── build_model_param_gbuf_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:534
#     │   │       ├── build_optimizer_group_ranges, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:550
#     │   │       │   └── <listcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:581
#     │   │       ├── build_model_and_main_param_groups, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:601
#     │   │       ├── get_model_param_buffer_dp_views, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:925
#     │   │       │   └── shard_buffer_among_dp_world, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:920
#     │   │       │       └── <listcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:923
#     │   │       └── <listcomp>, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:377
#     │   ├── get_batch, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:304
#     │   │   ├── <listcomp>, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:315
#     │   │   ├── <listcomp>, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:316
#     │   │   └── distribute_tensor, /root/vescale_prj/veScale/vescale/dtensor/api.py:154
#     │   │       ├── is_rng_supported_mesh, /root/vescale_prj/veScale/vescale/dtensor/random.py:37
#     │   │       ├── normalize_placements, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:47
#     │   │       ├── is_interleaved_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:30
#     │   │       ├── is_shard, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:24
#     │   │       ├── is_replicate, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:36
#     │   │       ├── _replicate_tensor, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:180
#     │   │       │   └── mesh_broadcast, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:231
#     │   │       └── __new__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:276
#     │   │           ├── _dispatch_torch_make_wrapper_subclass, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:250
#     │   │           └── __init__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:2
#     │   ├── _get_param_groups, /root/vescale_prj/veScale/vescale/optim/base_optimizer.py:103
#     │   ├── estimate_loss, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/finetune_4D.py:457
#     │   ├── zero_grad_buffer, /root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py:278
#     │   │   └── reset, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:424
#     │   │       └── reset, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:75
#     │   ├── forward, /root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py:184
#     │   │   └── forward, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:209
#     │   │       ├── _hook, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:96
#     │   │       │   ├── <genexpr>, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:130
#     │   │       │   │   └── <lambda>, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:98
#     │   │       │   │       └── _convert, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:77
#     │   │       │   └── <dictcomp>, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:131
#     │   │       ├── _hook, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:229
#     │   │       │   └── _convert, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:214
#     │   │       │       └── _convert_by_pi, /root/vescale_prj/veScale/vescale/dmodule/_hook.py:44
#     │   │       │           └── redistribute, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:505
#     │   │       │               └── forward, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:457
#     │   │       │                   ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:209
#     │   │       │                   └── redistribute_local_tensor, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:222
#     │   │       │                       ├── __eq__, /root/vescale_prj/veScale/vescale/dtensor/device_mesh.py:417
#     │   │       │                       ├── _decompose_reshard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:50
#     │   │       │                       ├── _replicate_then_shard, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:34
#     │   │       │                       └── _reshard_to_replicate_with_pad_one_dim, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:90
#     │   │       │                           ├── <listcomp>, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:106
#     │   │       │                           ├── <listcomp>, /root/vescale_prj/veScale/vescale/dtensor/redistribute.py:113
#     │   │       │                           └── mesh_all_gather, /root/vescale_prj/veScale/vescale/dtensor/_collective_utils.py:309
#     │   │       ├── forward, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:139
#     │   │       │   ├── forward, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:84
#     │   │       │   │   └── forward, /root/vescale_prj/veScale/vescale/model/patch/linear.py:48
#     │   │       │   └── forward, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:123
#     │   │       └── forward, /root/vescale_prj/veScale/examples/nanogpt_4D_finetune/model.py:50
#     │   ├── __torch_dispatch__, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:371
#     │   │   └── operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:377
#     │   │       ├── _bypass_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:161
#     │   │       │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_bypass.py:44
#     │   │       ├── _pre_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:193
#     │   │       │   ├── failed_on_mqa, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:145
#     │   │       │   └── apply, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:49
#     │   │       ├── _operator_dispatch, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:235
#     │   │       │   ├── unwrap_to_op_info, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:51
#     │   │       │   │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:2
#     │   │       │   │       └── __post_init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:133
#     │   │       │   │           └── <genexpr>, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:137
#     │   │       │   ├── propagate, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:154
#     │   │       │   │   ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:158
#     │   │       │   │   │   ├── <genexpr>, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:167
#     │   │       │   │   │   ├── <genexpr>, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:174
#     │   │       │   │   │   └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:406
#     │   │       │   │   │       ├── <genexpr>, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:409
#     │   │       │   │   │       ├── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:227
#     │   │       │   │   │       └── __hash__, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:381
#     │   │       │   │   └── propagate_op_sharding_non_cached, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:165
#     │   │       │   │       ├── <listcomp>, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:195
#     │   │       │   │       │   └── spec_to_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:170
#     │   │       │   │       ├── <dictcomp>, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:196
#     │   │       │   │       ├── pointwise_strategy, /root/vescale_prj/veScale/vescale/dtensor/ops/pointwise_ops.py:411
#     │   │       │   │       │   ├── is_partial, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:559
#     │   │       │   │       │   ├── <listcomp>, /root/vescale_prj/veScale/vescale/dtensor/ops/pointwise_ops.py:441
#     │   │       │   │       │   ├── max_num_shards, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:355
#     │   │       │   │       │   │   └── <listcomp>, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:359
#     │   │       │   │       │   │       └── num_shards, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:454
#     │   │       │   │       │   ├── output_shape, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:361
#     │   │       │   │       │   │   └── shape, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:442
#     │   │       │   │       │   ├── infer_broadcast_dims_map, /root/vescale_prj/veScale/vescale/dtensor/ops/utils.py:196
#     │   │       │   │       │   └── __init__, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:346
#     │   │       │   │       ├── _select_strategy, /root/vescale_prj/veScale/vescale/dtensor/sharding_prop.py:390
#     │   │       │   │       ├── args_spec, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:98
#     │   │       │   │       │   └── <genexpr>, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:107
#     │   │       │   │       └── return_type_tuple_tensors, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:153
#     │   │       │   ├── is_replicated, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:553
#     │   │       │   │   └── <genexpr>, /root/vescale_prj/veScale/vescale/dtensor/placement_types.py:557
#     │   │       │   ├── _is_inplace_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:37
#     │   │       │   ├── _is_out_variant_op, /root/vescale_prj/veScale/vescale/dtensor/op_schema.py:44
#     │   │       │   └── wrap, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:194
#     │   │       │       └── to_dt, /root/vescale_prj/veScale/vescale/dtensor/dispatch.py:195
#     │   │       └── _post_patch_for_dispatch, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:201
#     │   │           └── defer_resharding, /root/vescale_prj/veScale/vescale/dtensor/_dispatch_patch.py:134
#     │   │               └── _enable_autoresharding, /root/vescale_prj/veScale/vescale/dtensor/_diff.py:118
#     │   ├── finish_grad_sync, /root/vescale_prj/veScale/vescale/ddp/distributed_data_parallel.py:263
#     │   │   └── finish_grad_sync, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:449
#     │   │       └── finish_grad_sync, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:150
#     │   │           └── start_grad_sync, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:114
#     │   │               └── shard_buffer, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:86
#     │   │                   └── <listcomp>, /root/vescale_prj/veScale/vescale/ddp/grad_buffer.py:92
#     │   ├── step, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1234
#     │   │   ├── _copy_model_grads_to_main_grads, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1142
#     │   │   │   └── copy_group_grads, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1152
#     │   │   │       └── get_model_param_range_map, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:738
#     │   │   ├── clip_grad_norm, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1223
#     │   │   │   ├── get_parameters, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1263
#     │   │   │   ├── get_main_grads_for_grad_norm, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1270
#     │   │   │   │   ├── param_is_shared, /root/vescale_prj/veScale/vescale/optim/utils.py:62
#     │   │   │   │   └── param_is_sharded_or_replicate_on_first_rank, /root/vescale_prj/veScale/vescale/optim/utils.py:38
#     │   │   │   │       ├── <genexpr>, /root/vescale_prj/veScale/vescale/optim/utils.py:45
#     │   │   │   │       └── <genexpr>, /root/vescale_prj/veScale/vescale/optim/utils.py:47
#     │   │   │   └── clip_grad_norm_fp32, /root/vescale_prj/veScale/vescale/optim/clip_grads.py:21
#     │   │   ├── _copy_main_params_to_model_params, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1170
#     │   │   │   └── copy_group_params, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1180
#     │   │   └── _dispatch_gather_model_params, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:959
#     │   │       └── _copy_params_from_param_buffer, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:1078
#     │   ├── zero_grad, /root/vescale_prj/veScale/vescale/optim/distributed_optimizer.py:882
#     │   │   └── _zero_grad_group_helper, /root/vescale_prj/veScale/vescale/optim/utils.py:23
#     │   └── to_local, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:490
#     │       └── forward, /root/vescale_prj/veScale/vescale/dtensor/dtensor.py:204
#     └── __cleanup, /root/vescale_prj/veScale/vescale/checkpoint/api/vescale_checkpointer.py:234
#         ├── clear_cache, /root/vescale_prj/veScale/vescale/checkpoint/planner/vescale/vescale_planner.py:129
#         │   └── clear, /root/vescale_prj/veScale/vescale/checkpoint/planner/common.py:84
#         └── _cleanup_futures, /root/vescale_prj/veScale/vescale/checkpoint/api/base_checkpointer.py:62
#
# Breadth-First tree representation saved to logs/bfs_tree.log
